# %%
#抓租賃法規

from bs4 import BeautifulSoup
from splinter import Browser
import requests
import splinter
import json
import time

url = "http://www2.tmm.org.tw/pub/rentlaw-9.htm#pot02"
res = requests.get(url)
res.encoding = 'utf-8'
soup =BeautifulSoup(res.text,'lxml').select('#content')
# soup
jsonarray = []
jsondict = {}

jsondict['url'] = url
jsondict['update'] = '2017-08-23'
jsondict['html'] = res.text


jsonarray.append(jsondict)
with open('/home/ubuntu/Documents/Project_f/textmining/崔媽媽_租賃所有相關法規.json','w') as f:
    json.dump(jsonarray,f)
f.close()

# %%
from bs4 import BeautifulSoup
import requests

jsonarray = []
jsondict = {}

res = requests.get('http://www2.tmm.org.tw/pub/rentlaw-9.htm#pot02')
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text,'lxml').select('p')[1:-1]
[row.text.replace('\u3000','').replace('\r\n','').replace(' ','') for row in soup]

soup2 = BeautifulSoup(res.text,'lxml').select('#content')
list1 = [row.text.replace('\u3000','').replace('\r\n','').replace(' ','').split('\n') for row in soup2][0][1:-2]
list1[1:2]#法規名稱：民法第三節債之效力
list1[10:13]#法規名稱：民法第五節租賃
list1[107:108]#土地法第三編／第三章：房屋及基地租用
list1[128:129]#民事訴訟法（小額訴訟程序）

first = list1[1:9]
del first[3]

first_1_key = first[1][:5]+'定金'
first_1_value = first[1][5:]
first_2_key = first[2][:5]+'定金'
first_2_value = first[2][5:]+ first[3]+ first[4] + first[5] + first[6]

jsondict['url'] = 'http://www2.tmm.org.tw/pub/rentlaw-9.htm#pot02'
jsondict['update'] = '2017-09-02'
jsondict[first_1_key] = first_1_value
jsondict[first_2_key] = first_2_value


second = list1[10:107]
second_1_key = second[1]
second_1_value = second[2]

second_2_key = second[3]
second_2_value = ','.join(second[4:7])

second_3_key = second[7]
second_3_value = second[8]

second_4_key = second[9]
second_4_value = ','.join(second[10:12])

second_5_key = second[11]
second_5_value = ','.join(second[12:25])

second_6_key = second[25]
second_6_value = second[26]

second_7_key = second[27]
second_7_value = second[28]

second_8_key = second[29]
second_8_value = second[30]

second_9_key = second[31]
second_9_value = ','.join(second[32:34])

second_10_key = second[34]
second_10_value = ','.join(second[35:37])

second_11_key = second[37]
second_11_value = second[38]

second_12_key = second[39]
second_12_value = second[40]

second_13_key = second[41]
second_13_value = second[42]

second_14_key = second[43]
second_14_value = second[44]

second_15_key = second[45]
second_15_value = ','.join(second[46:48])

second_16_key = second[48]
second_16_value = ','.join(second[49:51])

second_17_key = second[51]
second_17_value = second[52]

second_18_key = second[53]
second_18_value = ','.join(second[54:56])

second_19_key = second[56]
second_19_value = second[57]

second_20_key = second[58]
second_20_value = second[59]

second_21_key = second[58]
second_21_value = second[59]

second_22_key = second[60]
second_22_value = ','.join(second[61:66])

second_23_key = second[66]
second_23_value = ','.join(second[67:70])

second_24_key = second[70]
second_24_value = ','.join(second[71:74])

second_25_key = second[74]
second_25_value = second[75]

second_26_key = second[76]
second_26_value = second[77]

second_27_key = second[78]
second_27_value = second[79]

second_28_key = second[80]+'耕作地'
second_28_value = ','.join(second[81:])

second_29_key = second[76]
second_29_value = second[77]

jsondict['url'] = 'http://www2.tmm.org.tw/pub/rentlaw-9.htm#pot02'
jsondict['update'] = '2017-09-02'
jsondict[second_1_key] = second_1_value
jsondict[second_2_key] = second_2_value
jsondict[second_3_key] = second_3_value
jsondict[second_4_key] = second_4_value
jsondict[second_5_key] = second_5_value
jsondict[second_6_key] = second_6_value
jsondict[second_7_key] = second_7_value
jsondict[second_8_key] = second_8_value
jsondict[second_9_key] = second_9_value
jsondict[second_10_key] = second_10_value
jsondict[second_11_key] = second_11_value
jsondict[second_12_key] = second_12_value
jsondict[second_13_key] = second_13_value
jsondict[second_14_key] = second_14_value
jsondict[second_15_key] = second_15_value
jsondict[second_16_key] = second_16_value
jsondict[second_17_key] = second_17_value
jsondict[second_18_key] = second_18_value
jsondict[second_19_key] = second_19_value
jsondict[second_20_key] = second_20_value
jsondict[second_21_key] = second_21_value
jsondict[second_22_key] = second_22_value
jsondict[second_23_key] = second_23_value
jsondict[second_24_key] = second_24_value
jsondict[second_25_key] = second_25_value
jsondict[second_26_key] = second_26_value
jsondict[second_27_key] = second_27_value
jsondict[second_28_key] = second_28_value
jsondict[second_29_key] = second_29_value


list1[107:128]#土地法第三編／第三章：房屋及基地租用

third = list1[107:128]

third_1_key = third[1]
third_1_value = ','.join(third[2:4])

third_2_key = third[4]
third_2_value = third[5]

third_3_key = third[6]
third_3_value = third[7]

third_4_key = third[8]
third_4_value = ','.join(third[9:11])

third_5_key = third[11]
third_5_value = ','.join(third[12:14])

third_6_key = third[14]
third_6_value = ','.join(third[15:17])

third_7_key = third[17]
third_7_value = ','.join(third[18:-1])

jsondict[third_1_key] = third_1_value
jsondict[third_2_key] = third_2_value
jsondict[third_3_key] = third_3_value
jsondict[third_4_key] = third_4_value
jsondict[third_5_key] = third_5_value
jsondict[third_6_key] = third_6_value
jsondict[third_7_key] = third_7_value



fourth = list1[128:]#民事訴訟法（小額訴訟程序）

fourth_1_key = fourth[1]+'小額訴訟'
fourth_1_value = ','.join(fourth[2:])

jsondict[fourth_1_key] = fourth_1_value


# [0:]
# second = list1[10:107]
# print(list1[10:107].index('不動產之租賃契約，其期限逾一年者，應以字據訂立之，未以字據訂立者，視為不定期限之租賃。'))
# jsonarray.append(jsondict)
# print(jsondict)

with open('崔媽媽租屋法律.json','w')as f:
    json.dump(jsondict,f)

# %%
#接力清洗

with open('崔媽媽租屋法律.json')as f:
    inn = f.read()
    outt = json.loads(inn)
    
jsonarray = []
keytuple = outt.keys()

keylist = list(aa)#2~38
i = 2
while i <39:
    jsondict = {}
    jsondict['url'] = outt['url']
    jsondict['update'] = '2017-09-02'
    jsondict['name'] = keylist[i]
    jsondict['content'] = outt[keylist[i]]
    jsonarray.append(jsondict)
    i += 1
    
with open('崔媽媽租屋法律_complete.json','w') as F:
    json.dump(jsonarray,F)
